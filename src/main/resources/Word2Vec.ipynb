# %%
"""
Created on Tue Jan 16 23:47:38 2024

@author: tahat
"""

import pandas as pd
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from collections import Counter
from subprocess import check_output

# %%
df = pd.read_excel('output_cleaned_no_empty_rows.xlsx')
sentences = df['Cümle'].tolist()

# %%
corpus = []
for sentence in sentences:
    # Check if the value is a string before splitting
    if isinstance(sentence, str):
        corpus.append(sentence.split())
    else:
        # Handle other types (e.g., convert to string or use a different strategy)
        corpus.append([])
        
print(len(corpus))
print(len(sentences))
# Out:
# 11744
# 11744

# %%
model = Word2Vec(corpus,vector_size=100,window=5,min_count=5,sg=1)
model.save('word2vec.model')

# %%
preprocessed_corpus = " ".join(map(str, sentences))
word_frequencies = Counter(preprocessed_corpus.split())
top_words = word_frequencies.most_common(20)

# %%
# Rapor
report = "En Fazla Geçen 20 Kelime:\n"
for word, frequency in top_words:
    report += f"{word}: {frequency} kez\n"

print(report)
# Out:
# En Fazla Geçen 20 Kelime:
# movie: 2101 kez
# like: 1281 kez
# film: 900 kez
# oppenheimer: 895 kez
# really: 730 kez
# nolan: 690 kez
# scene: 649 kez
# think: 619 kez
# bomb: 605 kez
# one: 602 kez
# felt: 597 kez
# time: 520 kez
# people: 514 kez
# didnt: 502 kez
# much: 482 kez
# see: 477 kez
# would: 472 kez
# im: 434 kez
# also: 431 kez
# good: 418 kez

# %%
# En sık geçen 20 kelimenin her biri için en benzer 5 kelimeyi bulun
similar_words_report = ""
sayac = 0
for word, frequency in top_words:
    sayac= sayac + 1
    similar_words_report += f"\nEn Benzer {sayac}. kelime '{word}' ({frequency} kez geçiyor):\n"
    
    try:
        similar_words = model.wv.most_similar(word, topn=5)
        for similar_word, similarity_score in similar_words:
            similar_words_report += f"{similar_word}: Benzerlik Skoru - {similarity_score}\n"
    except KeyError:
        similar_words_report += "Bu kelimenin Word2Vec modelde karşılığı yok.\n"

# Sonuçları raporlayın
print(similar_words_report)
# Out:
# En Benzer 1. kelime 'movie' (2101 kez geçiyor):
# boring: Benzerlik Skoru - 0.9614768624305725
# honestly: Benzerlik Skoru - 0.9590595364570618
# fast: Benzerlik Skoru - 0.9555848836898804
# overall: Benzerlik Skoru - 0.9549501538276672
# film: Benzerlik Skoru - 0.9532986879348755
#
# En Benzer 2. kelime 'like' (1281 kez geçiyor):
# feels: Benzerlik Skoru - 0.8877969980239868
# trailer: Benzerlik Skoru - 0.8835818767547607
# little: Benzerlik Skoru - 0.8826219439506531
# feel: Benzerlik Skoru - 0.8741145133972168
# bit: Benzerlik Skoru - 0.8673768639564514
#
# En Benzer 3. kelime 'film' (900 kez geçiyor):
# probably: Benzerlik Skoru - 0.9756174683570862
# heard: Benzerlik Skoru - 0.9710142016410828
# worst: Benzerlik Skoru - 0.9708309769630432
# favorite: Benzerlik Skoru - 0.968697726726532
# honestly: Benzerlik Skoru - 0.9685655832290649
#
# En Benzer 4. kelime 'oppenheimer' (895 kez geçiyor):
# communist: Benzerlik Skoru - 0.9542362689971924
# perspective: Benzerlik Skoru - 0.9382928609848022
# lewis: Benzerlik Skoru - 0.9382585883140564
# personal: Benzerlik Skoru - 0.9377946257591248
# trial: Benzerlik Skoru - 0.9362972974777222
#
# En Benzer 5. kelime 'really' (730 kez geçiyor):
# want: Benzerlik Skoru - 0.9485698342323303
# get: Benzerlik Skoru - 0.9455081224441528
# anything: Benzerlik Skoru - 0.9425164461135864
# enjoy: Benzerlik Skoru - 0.9424900412559509
# say: Benzerlik Skoru - 0.9379441142082214
#
# En Benzer 6. kelime 'nolan' (690 kez geçiyor):
# christopher: Benzerlik Skoru - 0.964097261428833
# fan: Benzerlik Skoru - 0.9552899599075317
# overall: Benzerlik Skoru - 0.9486501216888428
# interstellar: Benzerlik Skoru - 0.9486474990844727
# love: Benzerlik Skoru - 0.9427214860916138
#
# En Benzer 7. kelime 'scene' (649 kez geçiyor):
# speech: Benzerlik Skoru - 0.9002088308334351
# sequence: Benzerlik Skoru - 0.8885818123817444
# detonation: Benzerlik Skoru - 0.8876132369041443
# every: Benzerlik Skoru - 0.8787339329719543
# leading: Benzerlik Skoru - 0.8782306909561157
#
# En Benzer 8. kelime 'think' (619 kez geçiyor):
# say: Benzerlik Skoru - 0.9456033110618591
# id: Benzerlik Skoru - 0.9411163330078125
# christopher: Benzerlik Skoru - 0.9375405311584473
# honestly: Benzerlik Skoru - 0.9349197149276733
# love: Benzerlik Skoru - 0.9320166110992432
#
# En Benzer 9. kelime 'bomb' (605 kez geçiyor):
# atomic: Benzerlik Skoru - 0.9560636281967163
# bombs: Benzerlik Skoru - 0.9482517242431641
# actual: Benzerlik Skoru - 0.9367347955703735
# nuclear: Benzerlik Skoru - 0.9170819520950317
# atom: Benzerlik Skoru - 0.9165521860122681
#
# En Benzer 10. kelime 'one' (602 kez geçiyor):
# cinema: Benzerlik Skoru - 0.9550483226776123
# favorite: Benzerlik Skoru - 0.952061116695404
# year: Benzerlik Skoru - 0.9472299814224243
# easily: Benzerlik Skoru - 0.9315113425254822
# ever: Benzerlik Skoru - 0.9235801696777344
#
# En Benzer 11. kelime 'felt' (597 kez geçiyor):
# trailer: Benzerlik Skoru - 0.9228575825691223
# bit: Benzerlik Skoru - 0.9129952788352966
# feels: Benzerlik Skoru - 0.8911433815956116
# cut: Benzerlik Skoru - 0.8885508179664612
# little: Benzerlik Skoru - 0.8875364661216736
#
# En Benzer 12. kelime 'time' (520 kez geçiyor):
# second: Benzerlik Skoru - 0.9728396534919739
# half: Benzerlik Skoru - 0.9586864113807678
# night: Benzerlik Skoru - 0.9533501267433167
# two: Benzerlik Skoru - 0.948992908000946
# first: Benzerlik Skoru - 0.9467738270759583
#
# En Benzer 13. kelime 'people' (514 kez geçiyor):
# going: Benzerlik Skoru - 0.9470745325088501
# want: Benzerlik Skoru - 0.9439527988433838
# wanted: Benzerlik Skoru - 0.9377332925796509
# go: Benzerlik Skoru - 0.9321222901344299
# know: Benzerlik Skoru - 0.9224061369895935
#
# En Benzer 14. kelime 'didnt' (502 kez geçiyor):
# dont: Benzerlik Skoru - 0.9256224632263184
# get: Benzerlik Skoru - 0.9203083515167236
# really: Benzerlik Skoru - 0.9111679792404175
# wanted: Benzerlik Skoru - 0.909015417098999
# anything: Benzerlik Skoru - 0.9074167609214783
#
# En Benzer 15. kelime 'much' (482 kez geçiyor):
# anything: Benzerlik Skoru - 0.9643324613571167
# seem: Benzerlik Skoru - 0.9641067981719971
# enough: Benzerlik Skoru - 0.9620882272720337
# tell: Benzerlik Skoru - 0.9618486762046814
# either: Benzerlik Skoru - 0.9613202810287476
#
# En Benzer 16. kelime 'see' (477 kez geçiyor):
# go: Benzerlik Skoru - 0.9328883290290833
# need: Benzerlik Skoru - 0.932831883430481
# glad: Benzerlik Skoru - 0.930329442024231
# want: Benzerlik Skoru - 0.9150192737579346
# cant: Benzerlik Skoru - 0.9113881587982178
#
# En Benzer 17. kelime 'would' (472 kez geçiyor):
# actually: Benzerlik Skoru - 0.9742934703826904
# either: Benzerlik Skoru - 0.9579280614852905
# expecting: Benzerlik Skoru - 0.9540059566497803
# wrong: Benzerlik Skoru - 0.9539257287979126
# made: Benzerlik Skoru - 0.9532431960105896
#
# En Benzer 18. kelime 'im' (434 kez geçiyor):
# glad: Benzerlik Skoru - 0.9564667344093323
# need: Benzerlik Skoru - 0.9411537647247314
# say: Benzerlik Skoru - 0.9403857588768005
# ill: Benzerlik Skoru - 0.9359169006347656
# sure: Benzerlik Skoru - 0.9334245920181274
#
# En Benzer 19. kelime 'also' (431 kez geçiyor):
# directed: Benzerlik Skoru - 0.9794379472732544
# technically: Benzerlik Skoru - 0.9783782362937927
# genuinely: Benzerlik Skoru - 0.9779717326164246
# executed: Benzerlik Skoru - 0.9779263138771057
# fine: Benzerlik Skoru - 0.9778369069099426
#
# En Benzer 20. kelime 'good' (418 kez geçiyor):
# overall: Benzerlik Skoru - 0.9675657749176025
# though: Benzerlik Skoru - 0.9489992260932922
# enjoyed: Benzerlik Skoru - 0.9419320821762085
# thought: Benzerlik Skoru - 0.935448408126831
# great: Benzerlik Skoru - 0.9242103099822998

# %%
#Seçilen 5 cümle
selected_rows = [3628, 5202, 5904, 7781, 7927]
selected_sentences = df.iloc[selected_rows]['Cümle'].tolist()

# %%
# Her bir cümleye bir etiket (tag) atayın
tagged_data = [TaggedDocument(words=word_tokenize(sentence.lower()), tags=[str(idx)]) for idx, sentence in enumerate(sentences)]

# Doc2Vec modelini eğit
model = Doc2Vec(vector_size=100, window=5, min_count=1, workers=4, epochs=10)
model.build_vocab(tagged_data)
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# Modeli kaydetmek (isteğe bağlı)
model.save("doc2vec_model")

# %%
# Seçilen satırlardaki cümlelere benzerlik sorgusu yapmak için
for selected_row in selected_rows:
    selected_sentence = df.loc[selected_row, 'Cümle']
    
    # Bir cümle üzerinde benzerlik sorgusu yapmak için
    query_vector = model.infer_vector(word_tokenize(selected_sentence.lower()))
    similar_sentences = model.dv.most_similar([query_vector], topn=5)

    # Seçilen cümleyi ve benzer cümleleri göster
    print(f"\nTeslim edilen derlemedeki {selected_row}. cümle: {selected_sentence}")
    print(f"Bu cümleye benzeyen cümleler:")
    for idx, (sentence_index, similarity_score) in enumerate(similar_sentences, start=1):
        similar_sentence = sentences[int(sentence_index)]
        print(f"En benzer {idx}. cümle (Benzerlik Skoru: {similarity_score}): {similar_sentence}")
        
query_vector = model.infer_vector(word_tokenize(selected_sentence.lower()))
similar_sentences = model.dv.most_similar([query_vector], topn=5)

# Benzer cümleleri göster
for idx, (sentence_index, similarity_score) in enumerate(similar_sentences, start=1):
    print(f"En benzer {idx}. cümle (Benzerlik Skoru: {similarity_score}): {sentences[int(sentence_index)]}")
# Out:
# Teslim edilen derlemedeki 3628. cümle: still good movie wasnt horrifying visually awesome hoping
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.8060975670814514): negative sounding movie enjoyed thought good every time see nolan movie think hes one idea away making something great instead makes good movies still leagues ahead average movie hitting theater
# En benzer 2. cümle (Benzerlik Skoru: 0.7529678344726562): theres three maybe four really good movies could expand upon throughout nolans trying tell point left reeling times
# En benzer 3. cümle (Benzerlik Skoru: 0.7258433699607849): think best rdj performance need watch chaplin best performance
# En benzer 4. cümle (Benzerlik Skoru: 0.7154932618141174): think overall good movie im completely honest wasnt invested first acts
# En benzer 5. cümle (Benzerlik Skoru: 0.7149530649185181): watched movie felt like best christopher nolan movies years felt massive many actors yet felt intimate movie peeled layer oppenheimer weve never seen big screen cillian murphy stepped lead role executed precisely rdj also gave memorable performance strauss antagonist oppenheimer
#
# Teslim edilen derlemedeki 5202. cümle: ive never said movie good boring
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.8701468706130981): might would thought best movie id ever seen come
# En benzer 2. cümle (Benzerlik Skoru: 0.8379277586936951): probably best overall acting ive ever seen movie
# En benzer 3. cümle (Benzerlik Skoru: 0.8359861373901367): said best nolan film ive ever seen definitely issues
# En benzer 4. cümle (Benzerlik Skoru: 0.8243951201438904): seen one best films seen past years
# En benzer 5. cümle (Benzerlik Skoru: 0.819019615650177): easily best film ive seen last year
#
# Teslim edilen derlemedeki 5904. cümle: felt like badly written scene
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.9226834774017334): seemed like going storytelling device like version chapters every stage occurs atomic explosion
# En benzer 2. cümle (Benzerlik Skoru: 0.9154852628707886): felt movie meta commentary struss line oppenheimer wants trinity test hiroshimanagasaki
# En benzer 3. cümle (Benzerlik Skoru: 0.9132589101791382): jarring see dunkirk whopping extras bunch modern buildings background could fixed post trinity bomb test felt like bunch pyrotechnics someones backyard
# En benzer 4. cümle (Benzerlik Skoru: 0.911060631275177): get tension building get intention guess wanted atomic bomb feel like itd engulf like couldnt outrun like itd destroy entire city dont feel like scale conveyed nearly much hoped would
# En benzer 5. cümle (Benzerlik Skoru: 0.910582959651947): long long stretches film felt like trailers stitched together particularly considering tense score never lets especially youre needing focus conversation scene seemed go minute two
#
# Teslim edilen derlemedeki 7781. cümle: wonderful performances haunting ending
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.914734959602356): explosion finally showed lackluster underwhelming youve seen explosions old film tell gasoline explosion
# En benzer 2. cümle (Benzerlik Skoru: 0.9107101559638977): whole body clenching began trinity test showed everything silence sound waves bomb swept cast whole theater shaked thought genius move
# En benzer 3. cümle (Benzerlik Skoru: 0.9081865549087524): thought added showing mind worked wished brought back nd act leading trinity test
# En benzer 4. cümle (Benzerlik Skoru: 0.9080879092216492): appeared good movie explosion lacked uniqueness hoping resembling common gasoline explosion fast fire rather aweinspiring footage weve seen real trinity test
# En benzer 5. cümle (Benzerlik Skoru: 0.9061281681060791): also race create nazis eventually least though nazis defeated trinity gives important context eager build
#
# Teslim edilen derlemedeki 7927. cümle: boring hard keep since kept switching around past present future
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.7426239252090454): easily best thing since blood
# En benzer 2. cümle (Benzerlik Skoru: 0.7386513948440552): editing great made hour runtime fly part last minutes dragged bit
# En benzer 3. cümle (Benzerlik Skoru: 0.7236266732215881): people complaining last one hour issue first one hour felt like scenes werent interesting nothing much happening establishing oppenheimer leaning towards leftwing
# En benzer 4. cümle (Benzerlik Skoru: 0.7219550013542175): maybe missed mark something first act felt far chaotic cuts frantic
# En benzer 5. cümle (Benzerlik Skoru: 0.7210448384284973): favorite part film definitely last hour room questioning oppenheimers allegiance us
# En benzer 1. cümle (Benzerlik Skoru: 0.7787855863571167): easily best thing since blood
# En benzer 2. cümle (Benzerlik Skoru: 0.7658344507217407): one best films last decade one surreal polished biopics arguably nolans best film date
# En benzer 3. cümle (Benzerlik Skoru: 0.7577979564666748): last minutes probably rdjs best acting ive ever seen absolutely goosebump worthy performances around
# En benzer 4. cümle (Benzerlik Skoru: 0.7458580136299133): editing great made hour runtime fly part last minutes dragged bit
# En benzer 5. cümle (Benzerlik Skoru: 0.7419958114624023): one boring films ive ever seen joins dunkirk dune p almost fell asleep
