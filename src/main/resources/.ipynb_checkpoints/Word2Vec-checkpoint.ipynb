# %%
"""
Created on Tue Jan 16 23:47:38 2024

@author: tahat
"""

import pandas as pd
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from collections import Counter
from subprocess import check_output

# %%
df = pd.read_excel('output_cleaned_no_empty_rows.xlsx')
sentences = df['Cümle'].tolist()

# %%
corpus = []
for sentence in sentences:
    # Check if the value is a string before splitting
    if isinstance(sentence, str):
        corpus.append(sentence.split())
    else:
        # Handle other types (e.g., convert to string or use a different strategy)
        corpus.append([])
        
print(len(corpus))
print(len(sentences))
# Out:
# 11744
# 11744

# %%
model = Word2Vec(corpus,vector_size=100,window=5,min_count=5,sg=1)
model.save('word2vec.model')

# %%
preprocessed_corpus = " ".join(map(str, sentences))
word_frequencies = Counter(preprocessed_corpus.split())
top_words = word_frequencies.most_common(20)

# %%
# Rapor
report = "En Fazla Geçen 20 Kelime:\n"
for word, frequency in top_words:
    report += f"{word}: {frequency} kez\n"

print(report)
# Out:
# En Fazla Geçen 20 Kelime:
# movie: 2101 kez
# like: 1281 kez
# film: 900 kez
# oppenheimer: 895 kez
# really: 730 kez
# nolan: 690 kez
# scene: 649 kez
# think: 619 kez
# bomb: 605 kez
# one: 602 kez
# felt: 597 kez
# time: 520 kez
# people: 514 kez
# didnt: 502 kez
# much: 482 kez
# see: 477 kez
# would: 472 kez
# im: 434 kez
# also: 431 kez
# good: 418 kez

# %%
# En sık geçen 20 kelimenin her biri için en benzer 5 kelimeyi bulun
similar_words_report = ""
sayac = 0
for word, frequency in top_words:
    sayac= sayac + 1
    similar_words_report += f"\nEn Benzer {sayac}. kelime '{word}' ({frequency} kez geçiyor):\n"
    
    try:
        similar_words = model.wv.most_similar(word, topn=5)
        for similar_word, similarity_score in similar_words:
            similar_words_report += f"{similar_word}: Benzerlik Skoru - {similarity_score}\n"
    except KeyError:
        similar_words_report += "Bu kelimenin Word2Vec modelde karşılığı yok.\n"

# Sonuçları raporlayın
print(similar_words_report)
# Out:
# En Benzer 1. kelime 'movie' (2101 kez geçiyor):
# boring: Benzerlik Skoru - 0.9516264200210571
# overall: Benzerlik Skoru - 0.951373279094696
# honestly: Benzerlik Skoru - 0.9510888457298279
# definitely: Benzerlik Skoru - 0.9508646726608276
# film: Benzerlik Skoru - 0.9483299255371094
#
# En Benzer 2. kelime 'like' (1281 kez geçiyor):
# feels: Benzerlik Skoru - 0.8927971124649048
# little: Benzerlik Skoru - 0.8907674551010132
# trailer: Benzerlik Skoru - 0.8897271752357483
# bit: Benzerlik Skoru - 0.8867135047912598
# feel: Benzerlik Skoru - 0.8846341371536255
#
# En Benzer 3. kelime 'film' (900 kez geçiyor):
# probably: Benzerlik Skoru - 0.976925790309906
# since: Benzerlik Skoru - 0.972565770149231
# worst: Benzerlik Skoru - 0.9711790680885315
# heard: Benzerlik Skoru - 0.9702741503715515
# favorite: Benzerlik Skoru - 0.9693823456764221
#
# En Benzer 4. kelime 'oppenheimer' (895 kez geçiyor):
# communist: Benzerlik Skoru - 0.9594781398773193
# personal: Benzerlik Skoru - 0.944691002368927
# lewis: Benzerlik Skoru - 0.9428868293762207
# political: Benzerlik Skoru - 0.9412861466407776
# trial: Benzerlik Skoru - 0.9403226971626282
#
# En Benzer 5. kelime 'really' (730 kez geçiyor):
# want: Benzerlik Skoru - 0.9506934285163879
# get: Benzerlik Skoru - 0.9496299624443054
# say: Benzerlik Skoru - 0.9474316239356995
# enjoy: Benzerlik Skoru - 0.9453228116035461
# anything: Benzerlik Skoru - 0.9435041546821594
#
# En Benzer 6. kelime 'nolan' (690 kez geçiyor):
# christopher: Benzerlik Skoru - 0.9632627367973328
# fan: Benzerlik Skoru - 0.9591454863548279
# interstellar: Benzerlik Skoru - 0.9558731317520142
# overall: Benzerlik Skoru - 0.9473618865013123
# tenet: Benzerlik Skoru - 0.9452462792396545
#
# En Benzer 7. kelime 'scene' (649 kez geçiyor):
# speech: Benzerlik Skoru - 0.8979600071907043
# detonation: Benzerlik Skoru - 0.891822338104248
# sequence: Benzerlik Skoru - 0.8908148407936096
# silence: Benzerlik Skoru - 0.8816514015197754
# leading: Benzerlik Skoru - 0.8784700036048889
#
# En Benzer 8. kelime 'think' (619 kez geçiyor):
# say: Benzerlik Skoru - 0.9410016536712646
# christopher: Benzerlik Skoru - 0.9308717250823975
# id: Benzerlik Skoru - 0.930732011795044
# love: Benzerlik Skoru - 0.9276978969573975
# honestly: Benzerlik Skoru - 0.9259356260299683
#
# En Benzer 9. kelime 'bomb' (605 kez geçiyor):
# atomic: Benzerlik Skoru - 0.9586197137832642
# bombs: Benzerlik Skoru - 0.9499690532684326
# actual: Benzerlik Skoru - 0.9304239153862
# nuclear: Benzerlik Skoru - 0.9192882776260376
# atom: Benzerlik Skoru - 0.9139047861099243
#
# En Benzer 10. kelime 'one' (602 kez geçiyor):
# cinema: Benzerlik Skoru - 0.9514693021774292
# favorite: Benzerlik Skoru - 0.9506703615188599
# year: Benzerlik Skoru - 0.947669506072998
# easily: Benzerlik Skoru - 0.9303856492042542
# ever: Benzerlik Skoru - 0.9225727319717407
#
# En Benzer 11. kelime 'felt' (597 kez geçiyor):
# trailer: Benzerlik Skoru - 0.9257429242134094
# bit: Benzerlik Skoru - 0.9191510081291199
# little: Benzerlik Skoru - 0.9001633524894714
# two: Benzerlik Skoru - 0.8951109051704407
# feels: Benzerlik Skoru - 0.8889389634132385
#
# En Benzer 12. kelime 'time' (520 kez geçiyor):
# second: Benzerlik Skoru - 0.9725249409675598
# half: Benzerlik Skoru - 0.963762104511261
# two: Benzerlik Skoru - 0.953258216381073
# first: Benzerlik Skoru - 0.9528385996818542
# night: Benzerlik Skoru - 0.9493775367736816
#
# En Benzer 13. kelime 'people' (514 kez geçiyor):
# going: Benzerlik Skoru - 0.9514037370681763
# want: Benzerlik Skoru - 0.9512979984283447
# wanted: Benzerlik Skoru - 0.9445518851280212
# go: Benzerlik Skoru - 0.9356814026832581
# anything: Benzerlik Skoru - 0.929349422454834
#
# En Benzer 14. kelime 'didnt' (502 kez geçiyor):
# get: Benzerlik Skoru - 0.9364598989486694
# dont: Benzerlik Skoru - 0.9214599132537842
# really: Benzerlik Skoru - 0.9185132384300232
# wanted: Benzerlik Skoru - 0.9129850268363953
# know: Benzerlik Skoru - 0.9122397899627686
#
# En Benzer 15. kelime 'much' (482 kez geçiyor):
# anything: Benzerlik Skoru - 0.9692673683166504
# seem: Benzerlik Skoru - 0.9664552807807922
# enough: Benzerlik Skoru - 0.9664125442504883
# tell: Benzerlik Skoru - 0.9653977751731873
# either: Benzerlik Skoru - 0.9647668600082397
#
# En Benzer 16. kelime 'see' (477 kez geçiyor):
# need: Benzerlik Skoru - 0.9361392259597778
# go: Benzerlik Skoru - 0.9320647120475769
# glad: Benzerlik Skoru - 0.9319252967834473
# want: Benzerlik Skoru - 0.9156690835952759
# cant: Benzerlik Skoru - 0.9141703844070435
#
# En Benzer 17. kelime 'would' (472 kez geçiyor):
# actually: Benzerlik Skoru - 0.9705921411514282
# either: Benzerlik Skoru - 0.9605618119239807
# liked: Benzerlik Skoru - 0.9574440121650696
# expecting: Benzerlik Skoru - 0.9565433859825134
# made: Benzerlik Skoru - 0.9559139609336853
#
# En Benzer 18. kelime 'im' (434 kez geçiyor):
# glad: Benzerlik Skoru - 0.9634332060813904
# sure: Benzerlik Skoru - 0.9412831664085388
# say: Benzerlik Skoru - 0.9409527778625488
# need: Benzerlik Skoru - 0.9408982992172241
# ill: Benzerlik Skoru - 0.939166247844696
#
# En Benzer 19. kelime 'also' (431 kez geçiyor):
# directed: Benzerlik Skoru - 0.977580189704895
# genuinely: Benzerlik Skoru - 0.9774653315544128
# incredibly: Benzerlik Skoru - 0.9773477911949158
# executed: Benzerlik Skoru - 0.9768478870391846
# agree: Benzerlik Skoru - 0.9762038588523865
#
# En Benzer 20. kelime 'good' (418 kez geçiyor):
# overall: Benzerlik Skoru - 0.969620943069458
# though: Benzerlik Skoru - 0.9513446688652039
# enjoyed: Benzerlik Skoru - 0.9448628425598145
# thought: Benzerlik Skoru - 0.9393367767333984
# great: Benzerlik Skoru - 0.9246745109558105

# %%
#Seçilen 5 cümle
selected_rows = [3628, 5202, 5904, 7781, 8675]
selected_sentences = df.iloc[selected_rows]['Cümle'].tolist()

# %%
# Her bir cümleye bir etiket (tag) atayın
tagged_data = [TaggedDocument(words=word_tokenize(sentence.lower()), tags=[str(idx)]) for idx, sentence in enumerate(sentences)]

# Doc2Vec modelini eğit
model = Doc2Vec(vector_size=100, window=5, min_count=1, workers=4, epochs=10)
model.build_vocab(tagged_data)
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# Modeli kaydetmek (isteğe bağlı)
model.save("doc2vec_model")

# %%
# Seçilen satırlardaki cümlelere benzerlik sorgusu yapmak için
for selected_row in selected_rows:
    selected_sentence = df.loc[selected_row, 'Cümle']
    
    # Bir cümle üzerinde benzerlik sorgusu yapmak için
    query_vector = model.infer_vector(word_tokenize(selected_sentence.lower()))
    similar_sentences = model.dv.most_similar([query_vector], topn=5)

    # Seçilen cümleyi ve benzer cümleleri göster
    print(f"\nTeslim edilen derlemedeki {selected_row}. cümle: {selected_sentence}")
    print(f"Bu cümleye benzeyen cümleler:")
    for idx, (sentence_index, similarity_score) in enumerate(similar_sentences, start=1):
        similar_sentence = sentences[int(sentence_index)]
        print(f"En benzer {idx}. cümle (Benzerlik Skoru: {similarity_score}): {similar_sentence}")
        
query_vector = model.infer_vector(word_tokenize(query_sentence.lower()))
similar_sentences = model.dv.most_similar([query_vector], topn=5)

# Benzer cümleleri göster
for idx, (sentence_index, similarity_score) in enumerate(similar_sentences, start=1):
    print(f"En benzer {idx}. cümle (Benzerlik Skoru: {similarity_score}): {sentences[int(sentence_index)]}")
# Out:
# Teslim edilen derlemedeki 3628. cümle: still good movie wasnt horrifying visually awesome hoping
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.9547460079193115): murphys never better great see downey jr given meaty acting role damon settled gruff old man phase career blunt really stole last hour loved brief cameos big stars
# En benzer 2. cümle (Benzerlik Skoru: 0.9519737362861633): performances top notch cillian incredible shoe least best actor nomination still early call nice see robert downey jr interesting work knocking mcu feels like hes iron man last decade really nailed role
# En benzer 3. cümle (Benzerlik Skoru: 0.95076584815979): along direction fantastic acting everyone shoutout benny safdie oscarworthy cinematography hoyte another great score ludwig solid vfx almost perfect editing
# En benzer 4. cümle (Benzerlik Skoru: 0.9494118094444275): man josh hartnett perfect ernest lawrence loved benny safdie edward teller accent could thicker would harder understand eyebrows best part
# En benzer 5. cümle (Benzerlik Skoru: 0.9493907690048218): movie even released awards season think cillian murphy good sweep awards season based strong praise early oscar buzz hes getting playing iconic impactful figure modern oscar buzz pattern also gives cillian advantage doesnt oscar yet gives superiority oscar winning actors get nominated dicapriophoenix theyre gon na kill cry screen boost chances beat cillian
#
# Teslim edilen derlemedeki 5202. cümle: ive never said movie good boring
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.870171844959259): said best nolan film ive ever seen definitely issues
# En benzer 2. cümle (Benzerlik Skoru: 0.8585422039031982): idk thats enough get best makeup pretty much best ive ever seen
# En benzer 3. cümle (Benzerlik Skoru: 0.8539829254150391): seen one best films seen past years
# En benzer 4. cümle (Benzerlik Skoru: 0.8536808490753174): easily best film ive seen last year
# En benzer 5. cümle (Benzerlik Skoru: 0.8340190649032593): sure maybe best ever movies ive seen cinema best
#
# Teslim edilen derlemedeki 5904. cümle: felt like badly written scene
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.9028006196022034): silly though read book known going hour boring film switching flashbacks arguments conversations every minutes
# En benzer 2. cümle (Benzerlik Skoru: 0.9024224877357483): much third hour kinda worked felt like bw scenes strausss nomination felt little forced like needed counteract oppenheimer hearing scenes
# En benzer 3. cümle (Benzerlik Skoru: 0.9019338488578796): get tension building get intention guess wanted atomic bomb feel like itd engulf like couldnt outrun like itd destroy entire city dont feel like scale conveyed nearly much hoped would
# En benzer 4. cümle (Benzerlik Skoru: 0.8977740406990051): long long stretches film felt like trailers stitched together particularly considering tense score never lets especially youre needing focus conversation scene seemed go minute two
# En benzer 5. cümle (Benzerlik Skoru: 0.8970140814781189): bit messy around edges felt like time jumps first half muddle clarify
#
# Teslim edilen derlemedeki 7781. cümle: wonderful performances haunting ending
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.9106754064559937): scene bomb going incredible dude next breathing like tony soprano later seasons heard inhaling exhaling silence
# En benzer 2. cümle (Benzerlik Skoru: 0.9102740287780762): whole body clenching began trinity test showed everything silence sound waves bomb swept cast whole theater shaked thought genius move
# En benzer 3. cümle (Benzerlik Skoru: 0.9098913073539734): explosion finally showed lackluster underwhelming youve seen explosions old film tell gasoline explosion
# En benzer 4. cümle (Benzerlik Skoru: 0.9089431762695312): one second meets emily blunt chemistry next scene shes knocked next scene shes suddenly drunk poor relationship character development
# En benzer 5. cümle (Benzerlik Skoru: 0.9088689684867859): appeared good movie explosion lacked uniqueness hoping resembling common gasoline explosion fast fire rather aweinspiring footage weve seen real trinity test
#
# Teslim edilen derlemedeki 8675. cümle: film much better including completely irrelevant show
# Bu cümleye benzeyen cümleler:
# En benzer 1. cümle (Benzerlik Skoru: 0.8488561511039734): feel like point nolan getting took people going eisenhower wanted deny strauss fall people avoid nightmare scenario nuclear war
# En benzer 2. cümle (Benzerlik Skoru: 0.8427205085754395): get tension building get intention guess wanted atomic bomb feel like itd engulf like couldnt outrun like itd destroy entire city dont feel like scale conveyed nearly much hoped would
# En benzer 3. cümle (Benzerlik Skoru: 0.8414851427078247): techniques used actually interesting example one point flashback two characters talking dont need actually know said second character responds gets cut mid sentence liked
# En benzer 4. cümle (Benzerlik Skoru: 0.8397216200828552): could focused little guilt terror japanese people instead political brawl felt almost adam mckay style times wasnt huge cabinet position made fighting
# En benzer 5. cümle (Benzerlik Skoru: 0.8384349346160889): maybe im stupid non linear storytelling bit much
# En benzer 1. cümle (Benzerlik Skoru: 0.3597732484340668): good movie though
# En benzer 2. cümle (Benzerlik Skoru: 0.3539024889469147): thats felt like anyway
# En benzer 3. cümle (Benzerlik Skoru: 0.3271345794200897): really liked chernobyl series movie also pretty good film overall
# En benzer 4. cümle (Benzerlik Skoru: 0.3229239583015442): sound design movie incredible
# En benzer 5. cümle (Benzerlik Skoru: 0.322597861289978): theres also almost point watching imax except maybe one scene topographic shots
